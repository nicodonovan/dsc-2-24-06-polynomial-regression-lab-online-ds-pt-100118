# %% [markdown]
# # Polynomial Regression - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab you'll practice your knowledge on adding polynomial terms to your regression model!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
#
# - Understand how to account for non-linear relationships between predictors and target variable using polynomial terms

# %% [markdown]
# ## Create the best plot using polynomials!

# %% [markdown]
# Below, we created a plot with a clearly non-linear shape.
#
# - plot a polynomial function using `PolynomialFeatures` for polynomials up until the second, third and fourth degree.
# - print out the $R^2$ value for each of the three results. Draw conclusions with respect to which degree is best.

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

def pol(x):
    return x * np.cos(x)

x = np.linspace(0, 12, 100)
rng = np.random.RandomState(1234)
rng.shuffle(x)
x = np.sort(x[:25])
y = pol(x) + np.random.randn(25)*2

plt.scatter(x, y, color='green', s=50, marker='.')

plt.show();

# %% [markdown]
# ## Solution

# %%
## your code here
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
def pol(x):
    return x * np.cos(x)

x = np.linspace(0, 12, 100)
rng = np.random.RandomState(1234)
rng.shuffle(x)
x = np.sort(x[:25])
y = pol(x) + np.random.randn(25)*2

x_plot = np.linspace(0, 12, 100)

# reshape the arrays
X = x[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]

plt.scatter(x, y, color='green', s=50, marker='.', label="plot points")

poly = PolynomialFeatures(2)
X = poly.fit_transform(X)
X_plot = poly.fit_transform(X_plot)
reg_poly = LinearRegression().fit(X, y)
y_plot = reg_poly.predict(X_plot)

plt.plot(x_plot, y_plot)
plt.title("Second Degree")
plt.show()

print(r2_score(y, reg_poly.predict(X)))
# Out:
# 0.008367794531330741

# %%
def pol(x):
    return x * np.cos(x)

x = np.linspace(0, 12, 100)
rng = np.random.RandomState(1234)
rng.shuffle(x)
x = np.sort(x[:25])
y = pol(x) + np.random.randn(25)*2

x_plot = np.linspace(0, 12, 100)

# reshape the arrays
X = x[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]

plt.scatter(x, y, color='green', s=50, marker='.', label="plot points")

poly = PolynomialFeatures(3)
X = poly.fit_transform(X)
X_plot = poly.fit_transform(X_plot)
reg_poly = LinearRegression().fit(X, y)
y_plot = reg_poly.predict(X_plot)

plt.plot(x_plot, y_plot)
plt.title("Third Degree")
plt.show()

print(r2_score(y, reg_poly.predict(X)))
# Out:
# 0.1655247344737495

# %%
def pol(x):
    return x * np.cos(x)

x = np.linspace(0, 12, 100)
rng = np.random.RandomState(1234)
rng.shuffle(x)
x = np.sort(x[:25])
y = pol(x) + np.random.randn(25)*2

x_plot = np.linspace(0, 12, 100)

# reshape the arrays
X = x[:, np.newaxis]
X_plot = x_plot[:, np.newaxis]

plt.scatter(x, y, color='green', s=50, marker='.', label="plot points")

poly = PolynomialFeatures(4)
X = poly.fit_transform(X)
X_plot = poly.fit_transform(X_plot)
reg_poly = LinearRegression().fit(X, y)
y_plot = reg_poly.predict(X_plot)

plt.plot(x_plot, y_plot)
plt.title("Fourth Degree")
plt.show()

print(r2_score(y, reg_poly.predict(X)))
# Out:
# 0.7061249559434553

# %% [markdown]
# the fourth degree model had the highest R-squared value, indicating that it was the best fit for our data.

# %% [markdown]
# ## Summary

# %% [markdown]
# Great! You now know how to include polynomials in your linear model!
